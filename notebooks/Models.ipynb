# %% [markdown]
# # Projeto Big Data & Data Mining

# %% [markdown]
# ## Consumo de propagandas: impacto dos anúncios na decisão de compra dos consumidores

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Armazenamento

# %%
df = pd.read_csv("../Data/df_Social_Media_Tratado.csv", parse_dates=["Date"])
print("Dataset carregado com shape:", df.shape)
# Out:
# Dataset carregado com shape: (300000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Campaign_ID       300000 non-null  int64
#  1   Campaign_Goal     300000 non-null  object
#  2   Duration_in_Days  300000 non-null  int64
#  3   Channel_Used      300000 non-null  object
#  4   Conversion_Rate   300000 non-null  float64
#  5   Acquisition_Cost  300000 non-null  object
#  6   ROI               300000 non-null  float64
#  7   Location          300000 non-null  object
#  8   Language          300000 non-null  object
#  9   Clicks            300000 non-null  int64
#  10  Impressions       300000 non-null  int64
#  11  Engagement_Score  300000 non-null  int64
#  12  Customer_Segment  300000 non-null  object
#  13  Date              300000 non-null  datetime64[ns]
#  14  Company           300000 non-null  object
#  15  _Target_Audience  300000 non-null  object
#  16  Age_Min           300000 non-null  int64
#  17  Age_Max           300000 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(7), object(8)
# memory usage: 41.2+ MB

# %%
df.head(20)
# Out:
#     Campaign_ID     Campaign_Goal  Duration_in_Days Channel_Used  \
# 0        529013    Product Launch                15    Instagram
# 1        275352  Market Expansion                15     Facebook
# 2        692322    Product Launch                15    Instagram
# 3        675757    Increase Sales                15    Pinterest
# 4        535900  Market Expansion                15    Pinterest
# 5        323031    Product Launch                15     Facebook
# 6        727501    Increase Sales                15    Pinterest
# 7        289553    Product Launch                15    Pinterest
# 8        942511  Market Expansion                15      Twitter
# 9        255854    Increase Sales                15     Facebook
# 10       204863  Market Expansion                15    Instagram
# 11       147351    Increase Sales                15      Twitter
# 12       320183    Product Launch                15    Pinterest
# 13       998847    Increase Sales                15    Instagram
# 14       174406    Product Launch                15     Facebook
# 15       584909    Increase Sales                15    Instagram
# 16       414326  Market Expansion                15      Twitter
# 17       854283  Market Expansion                15     Facebook
# 18       372311    Product Launch                15      Twitter
# 19       687141   Brand Awareness                15      Twitter
#
#     Conversion_Rate Acquisition_Cost       ROI     Location Language  Clicks  \
# 0              0.15          $500.00  5.790000    Las Vegas  Spanish     500
# 1              0.01          $500.00  7.210000  Los Angeles   French     500
# 2              0.08          $500.00  0.430000       Austin  Spanish     500
# 3              0.03          $500.00  0.909824        Miami  Spanish     293
# 4              0.13          $500.00  1.422828       Austin   French     293
# 5              0.02          $500.00  6.900000       Austin  Spanish     500
# 6              0.10          $500.00  0.679240  Los Angeles   French     293
# 7              0.10          $500.00  1.009922        Miami  English     293
# 8              0.14          $500.00  1.190000  Los Angeles   French     501
# 9              0.04          $500.00  1.650000        Miami  English     501
# 10             0.08          $500.00  2.810000    Las Vegas  English     501
# 11             0.05          $500.00  5.020000       Austin  Spanish     501
# 12             0.04          $500.00  0.128698        Miami  Spanish     294
# 13             0.09          $500.00  0.940000    Las Vegas  Spanish     501
# 14             0.13          $500.00  0.890000       Austin  English     501
# 15             0.06          $500.00  7.320000     New York  Spanish     501
# 16             0.03          $500.00  4.080000  Los Angeles  English     502
# 17             0.05          $500.00  2.160000        Miami   French     502
# 18             0.02          $500.00  6.820000     New York   French     502
# 19             0.04          $500.00  5.260000        Miami   French     502
#
#     Impressions  Engagement_Score Customer_Segment       Date         Company  \
# 0          3000                 7           Health 2022-02-25      Aura Align
# 1          3000                 5             Home 2022-05-12  Hearth Harmony
# 2          3000                 9       Technology 2022-06-19   Cyber Circuit
# 3          1937                 1           Health 2022-09-08       Well Wish
# 4          1937                 1             Home 2022-08-24  Hearth Harmony
# 5          3001                10       Technology 2022-01-15   Cyber Circuit
# 6          1938                 1             Home 2022-10-30    Space Spruce
# 7          1938                 1             Food 2022-07-23   Feast Flavors
# 8          3003                 8             Food 2022-08-14  Culinary Quest
# 9          3003                 9             Food 2022-03-23   Gourmet Grove
# 10         3003                 8       Technology 2022-08-24    Silicon Saga
# 11         3004                 8          Fashion 2022-09-25      Mode Maven
# 12         1939                 1             Home 2022-03-05    Homely Haven
# 13         3005                 8       Technology 2022-06-11   Cyber Circuit
# 14         3005                 6           Health 2022-12-26      Aura Align
# 15         3005                 4             Food 2022-04-21   Gourmet Grove
# 16         3006                10           Health 2022-01-08      Aura Align
# 17         3006                 8       Technology 2022-08-20   Gadget Giants
# 18         3007                 9             Home 2022-04-23  Domestic Dream
# 19         3007                10           Health 2022-08-29        Heal Hub
#
#    _Target_Audience  Age_Min  Age_Max
# 0               Men       35       44
# 1             Women       45       60
# 2               Men       45       60
# 3               Men       25       34
# 4               Men       45       60
# 5             Women       35       44
# 6          All Ages       18       60
# 7               Men       25       34
# 8               Men       35       44
# 9             Women       45       60
# 10              Men       45       60
# 11            Women       25       34
# 12         All Ages       18       60
# 13              Men       18       24
# 14            Women       25       34
# 15            Women       25       34
# 16            Women       18       24
# 17              Men       25       34
# 18              Men       18       24
# 19              Men       25       34

# %% [markdown]
# ### Análise

# %% [markdown]
# #### Script

# %%
# 1. Prever Retorno Sobre Investimento (ROI)
# 2. Prever A Taxa de Conversão
# 3. Prever o canal de marketing que melhor teve performance (talvez o top 20 ou 30%)

# %% [markdown]
# #### 01. ROI

# %% [markdown]
# Seleção de variáveis

# %%
target = "ROI"

features = [
    "Duration_in_Days",
    "Conversion_Rate",
    "Clicks",
    "Impressions",
    "Engagement_Score",
    "Age_Min",
    "Age_Max",
    "Channel_Used",
    "Customer_Segment",
    "Language"
]

# %%
df_model = df[features + [target]].copy()

# %%
df_model = pd.get_dummies(df_model, drop_first=True)
print("Shape após dummies:", df_model.shape)
# Out:
# Shape após dummies: (300000, 17)

# %% [markdown]
# Treinamento do modelo

# %%
X = df_model.drop(columns=[target])
y = df_model[target]

# %%
import sys
print(sys.executable)

# !{sys.executable} -m pip --version
# !{sys.executable} -m pip install scikit-learn
# Out:
# c:\Users\Cleitin\BDDM\Consumo_propagandas\venv\Scripts\python.exe
# pip 25.3 from c:\Users\Cleitin\BDDM\Consumo_propagandas\venv\Lib\site-packages\pip (python 3.13)
#
# Requirement already satisfied: scikit-learn in c:\users\cleitin\bddm\consumo_propagandas\venv\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\cleitin\bddm\consumo_propagandas\venv\lib\site-packages (from scikit-learn) (2.3.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\cleitin\bddm\consumo_propagandas\venv\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\cleitin\bddm\consumo_propagandas\venv\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\cleitin\bddm\consumo_propagandas\venv\lib\site-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.25, 
    random_state=42
)

# %%
print("Treino:", X_train.shape, " | Teste:", X_test.shape)
# Out:
# Treino: (225000, 16)  | Teste: (75000, 16)

# %% [markdown]
# Treino do Modelo

# %%
from sklearn.linear_model import LinearRegression
modelo = LinearRegression()
modelo.fit(X_train, y_train)
print("Sucesso!!!")
# Out:
# Sucesso!!!

# %%
y_pred = modelo.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\n==== MÉTRICAS DO MODELO ====")
print("MSE :", mse)
print("RMSE:", np.sqrt(mse))
print("R²  :", r2)
# Out:
# ==== MÉTRICAS DO MODELO ====
# MSE : 4.04061555616764
# RMSE: 2.0101282437117387
# R²  : 0.33130995816040487

# %%
coef = pd.DataFrame({
    "variavel": X.columns,
    "coeficiente": modelo.coef_
})

print("\nCoeficientes ordenados:")
print(coef.sort_values("coeficiente", ascending=False).head(15))
# Out:
# Coeficientes ordenados:
#                        variavel   coeficiente
# 15             Language_Spanish  2.906368e-02
# 7        Channel_Used_Instagram  2.663886e-02
# 14              Language_French  2.634811e-02
# 9          Channel_Used_Twitter  1.798408e-02
# 13  Customer_Segment_Technology  1.616180e-02
# 11      Customer_Segment_Health  1.566556e-02
# 12        Customer_Segment_Home  1.387758e-02
# 10        Customer_Segment_Food  6.133340e-03
# 0              Duration_in_Days  4.654058e-04
# 6                       Age_Max  4.364792e-04
# 2                        Clicks  2.027028e-06
# 3                   Impressions -9.883280e-07
# 4              Engagement_Score -6.419417e-04
# 5                       Age_Min -9.386570e-04
# 1               Conversion_Rate -3.918335e-02
